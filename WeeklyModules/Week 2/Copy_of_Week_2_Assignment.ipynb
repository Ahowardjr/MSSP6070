# %% [markdown]
# Create a variable called 'spam' that contains [2, 4, 6, 8, 10].

# %%
spam = [2,4,6,8,10]

# %% [markdown]
# Created a variable named spam with 5 strings.

# %% [markdown]
# Assign the value of 'hello' as the third value in a list stored in a variable named 'spam.'

# %%
spam[2] = "hello"
spam
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# The third interger is represented as [2] since Python starts counting positions at 0. So[2] would be 0, [4] would be 1, [6] would be 2...etc

# %% [markdown]
# Show the code in a new cell:
#
# a. Create a variable called 'letters' that contains ['a',  'b',  'c', 'd'].

# %%
letters = ['a','b','c','d']
letters
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# Created a variable named letters with 4 strings.

# %% [markdown]
# Note to self: This code is a little different than the first code b/c letters are texts so and have no(requiring quotation marks), while numbers do have values.

# %% [markdown]
# b. What does letters[int(int('3'*2)//11)] evaluate to? Explain why in a comment.

# %%
letters[int(int('3'*2)//11)]
# Out:
# 'd'

# %% [markdown]
# Using order of operations:
# Pythin begins with ('3'*2). Since there is parentheses around 3, Pythin sees it as a text being multiplies by 2 equalling '33'

# %%
('3'*2)
# Out:
# '33'

# %% [markdown]
# Next is int('33')

# %%
int('33')
# Out:
# 33

# %%
33/11
# Out:
# 3.0

# %%
int(3)
# Out:
# 3

# %% [markdown]
# Last step is letters[3] and the d is the third index/string

# %%
letters[3]
# Out:
# 'd'

# %% [markdown]
# c. What does letters[-1] evaluate to? Explain why in a comment.

# %%
letters[-1]
# Out:
# 'd'

# %% [markdown]
# Python begins using negative numbers to count backwards from the end. For example letters[-3] would be 'b'

# %% [markdown]
# d. What does letters[:2] evaluate to? Explain why in a comment.

# %%
letters[:2]
# Out:
# ['a', 'b']

# %% [markdown]
# This equates to ['a', 'b'] because the colon accounts for everything before the before index 2('c')

# %% [markdown]
# How can you get the tuple form of the value of a list? How can you get the lists from a tuple? Show a code example in a new cell in the Notebook.

# %% [markdown]
# To get a tuple form of a value list use tuple()
# To get list from a tuple use list()

# %%
drink_list=['water','soda','juice']
drink_tuple=tuple(drink_list)
print(drink_tuple)
# Out:
# ('water', 'soda', 'juice')

# %%
drink_tuple=['water', 'soda','juice']
drink_list=list(drink_tuple)
print(drink_list)
# Out:
# ['water', 'soda', 'juice']

# %% [markdown]
# the difference between the two are the types of brackets/parenthesis

# %% [markdown]
# 5. Practice program (see Sweigart, Chapter Four, Comma Code Practice Project:
#
# a. spam = ['apples', 'bananas', 'tofu', 'cats']
#
# Write a function that accepts the list 'spam' as an argument and returns a string with all the items separated by a comma and a space, with 'and' inserted before the last item. The function should work with any list.

# %%
spam = ['apples', 'bananas', 'tofu', 'cats']

def comma_code(items):
    return ', '.join(items[:-1]) + ', and ' + items[-1]

print(comma_code(spam))
# Out:
# apples, bananas, tofu, and cats

# %% [markdown]
# items[:-1] selects every item except the last one.
#  ', '.join(...)` combines those items with a comma and space.
# items[-1]` selects the final item.
# ', and ' is placed immediately before that final item.
# comma_code(spam) passes the spam list into the function.
